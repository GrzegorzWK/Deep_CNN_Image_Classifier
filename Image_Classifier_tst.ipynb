# %% [markdown]
# ## 1. Setup and Load Data

# %% [markdown]
# ### 1.1. Install Dependencies and setup

# %%
# %pip install tensorflow 
# %pip install tensorflow-gpu 
# %pip install opencv-python 
# %pip install matplotlib
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.17.0-cp310-cp310-win_amd64.whl (2.0 kB)
# Collecting tensorflow-intel==2.17.0
#   Downloading tensorflow_intel-2.17.0-cp310-cp310-win_amd64.whl (385.0 MB)
#      -------------------------------------- 385.0/385.0 MB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\py\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\py\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.32.3)
# Collecting keras>=3.2.0
#   Downloading keras-3.6.0-py3-none-any.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\py\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.67.0)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Requirement already satisfied: setuptools in d:\py\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (75.2.0)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: wrapt>=1.11.0 in d:\py\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Collecting numpy<2.0.0,>=1.23.5
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#      --------------------------------------- 15.8/15.8 MB 50.2 MB/s eta 0:00:00
# Collecting flatbuffers>=24.3.25
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: termcolor>=1.1.0 in d:\py\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.5.0)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting h5py>=3.10.0
#   Downloading h5py-3.12.1-cp310-cp310-win_amd64.whl (3.0 MB)
#      ---------------------------------------- 3.0/3.0 MB 63.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\py\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.12.2)
# Collecting tensorboard<2.18,>=2.17
#   Downloading tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
#      ---------------------------------------- 5.5/5.5 MB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in d:\py\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: packaging in d:\py\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.1)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      ---------------------------------------- 71.9/71.9 KB ? eta 0:00:00
# Collecting ml-dtypes<0.5.0,>=0.3.1
#   Downloading ml_dtypes-0.4.1-cp310-cp310-win_amd64.whl (126 kB)
#      ---------------------------------------- 126.6/126.6 KB ? eta 0:00:00
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#      --------------------------------------- 26.4/26.4 MB 36.4 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 15.9 MB/s eta 0:00:00
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.44.0-py3-none-any.whl (67 kB)
#      ---------------------------------------- 67.1/67.1 KB ? eta 0:00:00
# Collecting optree
#   Downloading optree-0.13.0-cp310-cp310-win_amd64.whl (274 kB)
#      ------------------------------------- 274.7/274.7 KB 17.6 MB/s eta 0:00:00
# Collecting namex
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: rich in d:\py\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.9.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\py\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\py\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\py\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\py\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.10)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\py\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.2.3)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.7-py3-none-any.whl (106 kB)
#      ---------------------------------------- 106.3/106.3 KB ? eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\py\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.0.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\py\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\py\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in d:\py\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.2)
# Installing collected packages: namex, libclang, flatbuffers, wheel, tensorflow-io-gcs-filesystem, tensorboard-data-server, optree, opt-einsum, numpy, markdown, google-pasta, gast, absl-py, tensorboard, ml-dtypes, h5py, astunparse, keras, tensorflow-intel, tensorflow
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 flatbuffers-24.3.25 gast-0.6.0 google-pasta-0.2.0 h5py-3.12.1 keras-3.6.0 libclang-18.1.1 markdown-3.7 ml-dtypes-0.4.1 namex-0.0.8 numpy-1.26.4 opt-einsum-3.4.0 optree-0.13.0 tensorboard-2.17.1 tensorboard-data-server-0.7.2 tensorflow-2.17.0 tensorflow-intel-2.17.0 tensorflow-io-gcs-filesystem-0.31.0 wheel-0.44.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script wheel.exe is installed in 'd:\py\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script f2py.exe is installed in 'd:\py\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown_py.exe is installed in 'd:\py\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard.exe is installed in 'd:\py\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe, toco.exe and toco_from_protos.exe are installed in 'd:\py\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'd:\py\python.exe -m pip install --upgrade pip' command.
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [39 lines of output]
#       Traceback (most recent call last):
#         File "d:\py\lib\site-packages\packaging\requirements.py", line 36, in __init__
#           parsed = _parse_requirement(requirement_string)
#         File "d:\py\lib\site-packages\packaging\_parser.py", line 62, in parse_requirement
#           return _parse_requirement(Tokenizer(source, rules=DEFAULT_RULES))
#         File "d:\py\lib\site-packages\packaging\_parser.py", line 80, in _parse_requirement
#           url, specifier, marker = _parse_requirement_details(tokenizer)
#         File "d:\py\lib\site-packages\packaging\_parser.py", line 124, in _parse_requirement_details
#           marker = _parse_requirement_marker(
#         File "d:\py\lib\site-packages\packaging\_parser.py", line 145, in _parse_requirement_marker
#           tokenizer.raise_syntax_error(
#         File "d:\py\lib\site-packages\packaging\_tokenizer.py", line 167, in raise_syntax_error
#           raise ParserSyntaxError(
#       packaging._tokenizer.ParserSyntaxError: Expected end or semicolon (after name and no valid version specifier)
#           python_version>"3.7"
#                         ^
#
#       The above exception was the direct cause of the following exception:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\grzeg\AppData\Local\Temp\pip-install-ojcl9n5o\tensorflow-gpu_aea2d3f00ff54bd586a3a07b02c65179\setup.py", line 40, in <module>
#           setuptools.setup()
#         File "d:\py\lib\site-packages\setuptools\__init__.py", line 116, in setup
#           _install_setup_requires(attrs)
#         File "d:\py\lib\site-packages\setuptools\__init__.py", line 87, in _install_setup_requires
#           dist.parse_config_files(ignore_option_errors=True)
#         File "d:\py\lib\site-packages\setuptools\dist.py", line 649, in parse_config_files
#           self._finalize_requires()
#         File "d:\py\lib\site-packages\setuptools\dist.py", line 383, in _finalize_requires
#           self._normalize_requires()
#         File "d:\py\lib\site-packages\setuptools\dist.py", line 398, in _normalize_requires
#           self.install_requires = list(map(str, _reqs.parse(install_requires)))
#         File "d:\py\lib\site-packages\packaging\requirements.py", line 38, in __init__
#           raise InvalidRequirement(str(e)) from e
#       packaging.requirements.InvalidRequirement: Expected end or semicolon (after name and no valid version specifier)
#           python_version>"3.7"
#                         ^
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'd:\py\python.exe -m pip install --upgrade pip' command.
# Collecting opencv-python
#   Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#      ---------------------------------------- 38.8/38.8 MB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.3 in d:\py\lib\site-packages (from opencv-python) (1.26.4)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'd:\py\python.exe -m pip install --upgrade pip' command.
# Collecting matplotlib
#   Downloading matplotlib-3.9.2-cp310-cp310-win_amd64.whl (7.8 MB)
#      ---------------------------------------- 7.8/7.8 MB 29.4 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.3.1 in d:\py\lib\site-packages (from matplotlib) (3.0.8)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.9/55.9 KB ? eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp310-cp310-win_amd64.whl (216 kB)
#      ------------------------------------- 216.0/216.0 KB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23 in d:\py\lib\site-packages (from matplotlib) (1.26.4)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.54.1-cp310-cp310-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 2.9 MB/s eta 0:00:00
# Collecting pillow>=8
#   Downloading pillow-11.0.0-cp310-cp310-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 2.6/2.6 MB 54.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in d:\py\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\py\lib\site-packages (from matplotlib) (2.8.2)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: six>=1.5 in d:\py\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.54.1 kiwisolver-1.4.7 matplotlib-3.9.2 pillow-11.0.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'd:\py\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'd:\py\python.exe -m pip install --upgrade pip' command.

# %%
# %pip list
# Out:
# Package                                  Version
# ---------------------------------------- ------------
# absl-py                                  2.1.0
# aiohappyeyeballs                         2.4.3
# aiohttp                                  3.10.10
# aiosignal                                1.3.1
# alembic                                  1.13.3
# anyio                                    4.6.2.post1
# apache-airflow                           2.10.2
# apache-airflow-providers-common-compat   1.2.1
# apache-airflow-providers-common-io       1.4.2
# apache-airflow-providers-common-sql      1.18.0
# apache-airflow-providers-fab             1.4.1
# apache-airflow-providers-ftp             3.11.1
# apache-airflow-providers-http            4.13.1
# apache-airflow-providers-imap            3.7.0
# apache-airflow-providers-smtp            1.8.0
# apache-airflow-providers-sqlite          3.9.0
# apispec                                  6.7.0
# argcomplete                              3.5.1
# asgiref                                  3.8.1
# asttokens                                2.0.5
# astunparse                               1.6.3
# async-timeout                            4.0.3
# attrs                                    24.2.0
# babel                                    2.16.0
# backcall                                 0.2.0
# blinker                                  1.8.2
# cachelib                                 0.9.0
# certifi                                  2024.8.30
# cffi                                     1.17.1
# charset-normalizer                       3.4.0
# click                                    8.1.7
# clickclick                               20.10.2
# colorama                                 0.4.4
# colorlog                                 6.8.2
# ConfigUpdater                            3.2
# connexion                                2.14.2
# contourpy                                1.3.0
# cron-descriptor                          1.4.5
# croniter                                 3.0.3
# cryptography                             43.0.3
# cycler                                   0.12.1
# debugpy                                  1.6.0
# decorator                                5.1.1
# Deprecated                               1.2.14
# dill                                     0.3.9
# dnspython                                2.7.0
# docutils                                 0.21.2
# email_validator                          2.2.0
# entrypoints                              0.4
# exceptiongroup                           1.2.2
# executing                                0.8.3
# Flask                                    2.2.5
# Flask-AppBuilder                         4.5.0
# Flask-Babel                              2.0.0
# Flask-Caching                            2.3.0
# Flask-JWT-Extended                       4.6.0
# Flask-Limiter                            3.8.0
# Flask-Login                              0.6.3
# Flask-Session                            0.5.0
# Flask-SQLAlchemy                         2.5.1
# Flask-WTF                                1.2.1
# flatbuffers                              24.3.25
# fonttools                                4.54.1
# frozenlist                               1.4.1
# fsspec                                   2024.10.0
# gast                                     0.6.0
# google-pasta                             0.2.0
# google-re2                               1.1.20240702
# googleapis-common-protos                 1.65.0
# greenlet                                 3.1.1
# grpcio                                   1.67.0
# gunicorn                                 23.0.0
# h11                                      0.14.0
# h5py                                     3.12.1
# httpcore                                 1.0.6
# httpx                                    0.27.2
# idna                                     3.10
# importlib_metadata                       8.4.0
# importlib_resources                      6.4.5
# inflection                               0.5.1
# ipykernel                                6.13.0
# ipython                                  8.2.0
# itsdangerous                             2.2.0
# jedi                                     0.18.1
# Jinja2                                   3.1.4
# jmespath                                 1.0.1
# jsonschema                               4.23.0
# jsonschema-specifications                2024.10.1
# jupyter-client                           7.2.2
# jupyter-core                             4.9.2
# keras                                    3.6.0
# kiwisolver                               1.4.7
# lazy-object-proxy                        1.10.0
# libclang                                 18.1.1
# limits                                   3.13.0
# linkify-it-py                            2.0.3
# lockfile                                 0.12.2
# Mako                                     1.3.6
# Markdown                                 3.7
# markdown-it-py                           3.0.0
# MarkupSafe                               3.0.2
# marshmallow                              3.23.0
# marshmallow-oneofschema                  3.1.1
# marshmallow-sqlalchemy                   0.28.2
# matplotlib                               3.9.2
# matplotlib-inline                        0.1.3
# mdit-py-plugins                          0.4.2
# mdurl                                    0.1.2
# methodtools                              0.4.7
# ml-dtypes                                0.4.1
# more-itertools                           10.5.0
# multidict                                6.1.0
# namex                                    0.0.8
# nest-asyncio                             1.5.5
# numpy                                    1.26.4
# opencv-python                            4.10.0.84
# opentelemetry-api                        1.27.0
# opentelemetry-exporter-otlp              1.27.0
# opentelemetry-exporter-otlp-proto-common 1.27.0
# opentelemetry-exporter-otlp-proto-grpc   1.27.0
# opentelemetry-exporter-otlp-proto-http   1.27.0
# opentelemetry-proto                      1.27.0
# opentelemetry-sdk                        1.27.0
# opentelemetry-semantic-conventions       0.48b0
# opt_einsum                               3.4.0
# optree                                   0.13.0
# ordered-set                              4.1.0
# packaging                                24.1
# parso                                    0.8.3
# pathspec                                 0.12.1
# pendulum                                 3.0.0
# pickleshare                              0.7.5
# pillow                                   11.0.0
# pip                                      22.0.4
# pluggy                                   1.5.0
# prison                                   0.2.1
# prompt-toolkit                           3.0.29
# propcache                                0.2.0
# protobuf                                 4.25.5
# psutil                                   5.9.0
# pure-eval                                0.2.2
# pycparser                                2.22
# Pygments                                 2.18.0
# PyJWT                                    2.9.0
# pyparsing                                3.0.8
# python-daemon                            3.0.1
# python-dateutil                          2.8.2
# python-nvd3                              0.16.0
# python-slugify                           8.0.4
# pytz                                     2024.2
# pywin32                                  303
# PyYAML                                   6.0.2
# pyzmq                                    22.3.0
# referencing                              0.35.1
# requests                                 2.32.3
# requests-toolbelt                        1.0.0
# rfc3339-validator                        0.1.4
# rich                                     13.9.3
# rich-argparse                            1.5.2
# rpds-py                                  0.20.0
# setproctitle                             1.3.3
# setuptools                               75.2.0
# six                                      1.16.0
# sniffio                                  1.3.1
# SQLAlchemy                               1.4.54
# SQLAlchemy-JSONField                     1.0.2
# SQLAlchemy-Utils                         0.41.2
# sqlparse                                 0.5.1
# stack-data                               0.2.0
# tabulate                                 0.9.0
# tenacity                                 9.0.0
# tensorboard                              2.17.1
# tensorboard-data-server                  0.7.2
# tensorflow                               2.17.0
# tensorflow-intel                         2.17.0
# tensorflow-io-gcs-filesystem             0.31.0
# termcolor                                2.5.0
# text-unidecode                           1.3
# time-machine                             2.16.0
# tornado                                  6.1
# traitlets                                5.1.1
# typing_extensions                        4.12.2
# tzdata                                   2024.2
# uc-micro-py                              1.0.3
# unicodecsv                               0.14.1
# universal_pathlib                        0.2.5
# urllib3                                  2.2.3
# wcwidth                                  0.2.5
# Werkzeug                                 2.2.3
# wheel                                    0.44.0
# wirerope                                 0.4.7
# wrapt                                    1.16.0
# WTForms                                  3.2.1
# yarl                                     1.16.0
# zipp                                     3.20.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'd:\py\python.exe -m pip install --upgrade pip' command.

# %%
import tensorflow as tf
import os

# os is used for merging folder paths with a homogeneous type across all operating systems and can show all items in a directory

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth - help to prevet OOM errors, we take all our gpus 

gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ### 1.2. Remove dodgy images
